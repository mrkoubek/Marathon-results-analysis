# %% [markdown]
# # WIP
# ## IES - Python - Project
# ### Marathon Results Analysis
# #### David Koubek, Jiri Zelenka

# %% [markdown]
# #### Import required packages.

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
from IPython.core.debugger import Tracer

# %% [markdown]
# ### Robots.txt
#
# Are we allowed to scrape?

# %%
requests.get('https://www.runczech.com/robots.txt')
# Out:
# <Response [200]>

# %% [markdown]
# The response 200 means the request was fulfilled. Let's look visually at the actual robots.txt file what is allowed and what's not.

# %%
print(requests.get('https://www.runczech.com/robots.txt').text)
# Out:
# #
# # robots.txt
# #
#
# # exclude these directories
# User-agent: *
# Disallow: /srv/
# Disallow: /cgi/
# Allow: /srv/www/qf/*/ramjet/eventList
# Allow: /srv/www/qf/*/ramjet/eventVoucherList
# Allow: /srv/www/qf/*/ramjet/contactPage
# Allow: /srv/www/qf/*/ramjet/raceDetail
# Allow: /srv/www/qf/*/ramjet/leagueDetail
# Allow: /srv/www/qf/*/ramjet/results/list
# Allow: /srv/www/qf/*/ramjet/results/league
# Allow: /srv/www/qf/*/ramjet/results/league/detail
# Allow: /srv/www/qf/*/ramjet/resultsEventDetail
# Allow: /srv/www/qf/*/ramjet/resultsSubEventUserDetail
# Allow: /srv/www/qf/*/ramjet/resultsSubEventGroupDetail
# Allow: /srv/www/qf/*/ramjet/event/runnerList
#
# Sitemap: https://www.runczech.com/sitemap-cs.xml
# Sitemap: https://www.runczech.com/sitemap-en.xml
# Sitemap: https://www.runczech.com/sitemap-de.xml
# Sitemap: https://www.runczech.com/sitemap-it.xml
# Sitemap: https://www.runczech.com/sitemap-fr.xml
# Sitemap: https://www.runczech.com/sitemap-es.xml
# Sitemap: https://www.runczech.com/sitemap-pl.xml
# Sitemap: https://www.runczech.com/sitemap-zh.xml
# Sitemap: https://www.runczech.com/sitemap-ru.xml
# Sitemap: https://www.runczech.com/sitemap-hu.xml
# Sitemap: https://www.runczech.com/sitemap-ja.xml

# %% [markdown]
# The "resultsEventDetail" which we desire to scrape is allowed which is good, we can proceed.

# %% [markdown]
# ## Pages

# %%
def getSoup(link):
    r = requests.get(link)
    r.encoding = 'UTF-8'
    return BeautifulSoup(r.text,'lxml')

# %% [markdown]
# ### Scrape the whole HTML of a single link

# %%
def getAllLinks(link):
    soup = getSoup(link)

    return soup # temporarily return just the whole HTML to make sure at least this works
    
marathons_links = getAllLinks('https://www.runczech.com/srv/www/qf/en/ramjet/results/list?&page=1&per_page=15')

# %%
marathons_links
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 7 ]><html class="nojs ie ie7" lang="en"><![endif]--><!--[if IE 8 ]><html class="nojs ie ie8" lang="en"><![endif]--><!--[if IE 9 ]><html class="nojs ie ie9" lang="en"><![endif]--><!--[if !IE]><!--><html class="nojs" lang="en"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>Results | RunCzech</title>
# <meta content="index, follow" name="robots"/>
# <meta content="index, follow, snippet, archive" name="googlebot"/>
# <meta content="FG Forrest, a.s., www.fg.cz, 2013" name="author"/>
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# <link href="https://cdn-vsh.runczech.com/favicon.ico#v=2018" rel="shortcut icon" type="image/x-icon"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/en/rss/news.xml" rel="alternate" title="RunCzech - News" type="application/rss+xml"/>
# <link href="https://cdn-vsh.runczech.com/ver/20180712094528/css/u/fg-skeleton.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://cdn-vsh.runczech.com/ver/20190527113827/css/u/main.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://cdn-vsh.runczech.com/ver/20131001171016/js/u/plugins/highslide/highslide.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://cdn-vsh.runczech.com/js/u/plugins/jquery-ui/css/pim/jquery-ui-1.10.3.custom.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://cdn-vsh.runczech.com/js/u/plugins/jquery-ui/css/pim/jquery.ui.all-1.8.16.css" media="all" rel="stylesheet" type="text/css"/>
# <script>
# 	document.documentElement.className = document.documentElement.className.replace( /(?:^|\s)nojs(?!\S)/ , '' );
# 	document.documentElement.className += ' js';
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js"></script>
# <script src="//ajax.googleapis.com/ajax/libs/swfobject/2.2/swfobject.js"></script>
# <script>window.jQuery || document.write('<script src="https://cdn-vsh.runczech.com/ver/20130806135600/js/u/jquery-1.8.3.min.js"><\/script>')</script>
# <script src="https://cdn-vsh.runczech.com/ver/20130806135600/js/u/plugins/highslide/highslide-full.packed.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20130806135600/js/u/jquery.ajaxmanager.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20161031132654/js/u/jquery.partialUpdate.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20161031132654/js/u/jquery.liveValidation.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20181121102538/js/u/plugins/jquery-ui/script/jquery-ui-1.10.3.custom.min.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20181121102538/js/u/plugins/jquery-ui/script/jquery-ui-setting-en.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20190321145359/js/u/plugins/jquery-ui/script/jquery.ui.timepicker-0.9.6.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20181121102538/js/u/plugins/jquery-ui/script/jquery.ui.timepicker-en-1.8.16.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20180412124445/js/en/locale.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20180712094528/js/u/plugins/highslide/highslide-settings.js"></script>
# <script src="/srv/www/cs/runnerProfile/getLoggedUserInfo"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20150730165504/js/u/jquery.jsAutocomplete.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20190528152553/js/u/main.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20131007225202/js/u/image-cropper.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20180115230313/js/u/plugins/instafeed.min.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20180115230313/js/u/plugins/svg4everybody.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20180115230313/js/u/plugins/isMobile.js"></script>
# <script src="https://cdn-vsh.runczech.com/ver/20180307162440/js/u/plugins/smart-app-banner.js"></script>
# <!--[if lt IE 9]><script src="/ver/19700101010000/js/u/html5.js"></script><![endif]-->
# <link href="https://cdn-vsh.runczech.com/img/u/apple-touch-icon-iphone.png" rel="apple-touch-icon"/>
# <link href="https://cdn-vsh.runczech.com/img/u/apple-touch-icon-ipad.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://cdn-vsh.runczech.com/img/u/apple-touch-icon-iphone4.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://cdn-vsh.runczech.com/img/u/android-touch-icon.png" rel="android-touch-icon" sizes="192x192"/>
# <meta content="Results | RunCzech" property="og:title"/>
# <meta content="runczech.com" property="og:site_name"/>
# <meta content="" property="og:description"/>
# <meta content="https://cdn-vsh.runczech.com/img/u/results/FB_share_graph.png" property="og:image"/>
# <meta content="app-id=1356117069" name="apple-itunes-app"/>
# <meta content="app-id=cz.runczech.android" name="google-play-app"/>
# <meta content="FgkFXb3bQ8ahP521Z86IbIf_yPoNc2CQ0sWO3MU0wro" name="google-site-verification"/>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TBQL8N" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-TBQL8N');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body id="results">
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# 		  var js, fjs = d.getElementsByTagName(s)[0];
# 		  if (d.getElementById(id)) return;
# 		  js = d.createElement(s); js.id = id;
# 		  js.src = "//connect.facebook.net/cs_CZ/sdk.js";
# 		  fjs.parentNode.insertBefore(js, fjs);
# 		}(document, 'script', 'facebook-jssdk'));</script>
# <script>
# 		// <![CDATA[
# 			$("body").addClass("jsEnabled");
# 		// ]]>
# 		</script>
# <header class="pageHeader js_pageHeader">
# <div class="pageHeader_container pageHeader_container-main">
# <p class="logo"><a class="logo_link" href="/en/"><img alt="RunCzech" class="logo_image" height="38" src="https://cdn-vsh.runczech.com/img/u/logo-run-czech.svg#ico" width="160"/></a></p>
# <div class="megaBurger_wrapper">
# <a class="menuBurger js_menuBurger" href="#mainMenu">
# <span class="menuBurger_lines"></span>
# <span class="menuBurger_text">Menu</span>
# </a>
# </div>
# <nav class="mainMenu navigation" id="navigation">
# <h2 class="visuallyHidden">Main menu</h2>
# <p class="skip"><a href="#content">Skip to content</a></p>
# <ul class="mainMenu_list js_mainMenu" id="mainMenu">
# <li class="mainMenu_item"><a class="mainMenu_link" data-megamenu="events" href="/en/events/index.shtml">Events</a></li>
# <li class="mainMenu_item"><a class="mainMenu_link" data-megamenu="results" href="/srv/www/qf/en/ramjet/results/list">Results</a></li>
# <li class="mainMenu_item"><a class="mainMenu_link" data-megamenu="league" href="/en/running-league/running-league/you-do-not-have-to-run-first-to-be-the-winner/index.shtml">Running league</a></li>
# <li class="mainMenu_item"><a class="mainMenu_link" data-megamenu="forYou" href="/en/for-you/for-runners/rules-and-general-information-1/index.shtml">For you</a></li>
# <li class="mainMenu_item"><a class="mainMenu_link" data-megamenu="photoVideo" href="/en/photo-and-video/index.shtml">Photo &amp; video</a></li>
# <li class="mainMenu_item"><a class="mainMenu_link" data-megamenu="aboutUs" href="/srv/www/qf/en/ramjet/contactPage">Useful</a></li>
# </ul>
# <p class="skip"><a href="#submenu">Skip to detailed offer</a></p>
# </nav>
# </div>
# <div class="pageHeader_container pageHeader_container-bar">
# <div class="pageHeader_container_part">
# <div class="pageHeader_socialMedia">
# <ul class="pageHeader_socialMedia_list">
# <li class="pageHeader_socialMedia_item">
# <a class="pageHeader_socialMedia_link pageHeader_socialMedia_link-facebook" href="https://www.facebook.com/runczech" rel="noopener" target="_blank" title="Prague International Marathon na Facebooku"><svg class="svg-icon"><use xlink:href="#icon-social-media-facebook"></use></svg> <span class="sr-only">Prague International Marathon na Facebooku</span></a>
# </li>
# <li class="pageHeader_socialMedia_item">
# <a class="pageHeader_socialMedia_link pageHeader_socialMedia_link-twitter" href="https://twitter.com/RunCzech" rel="noopener" target="_blank" title="Prague International Marathon na Twitteru"><svg class="svg-icon"><use xlink:href="#icon-social-media-twitter"></use></svg> <span class="sr-only">Prague International Marathon na Twitteru</span></a>
# </li>
# <li class="pageHeader_socialMedia_item">
# <a class="pageHeader_socialMedia_link pageHeader_socialMedia_link-flickr" href="https://www.flickr.com/photos/runczech/" rel="noopener" target="_blank" title="Prague International Marathon na Flickru"><svg class="svg-icon"><use xlink:href="#icon-social-media-flickr"></use></svg> <span class="sr-only">Prague International Marathon na Flickru</span></a>
# </li>
# <li class="pageHeader_socialMedia_item">
# <a class="pageHeader_socialMedia_link pageHeader_socialMedia_link-instagram" href="https://www.instagram.com/runczech/?hl=cs" rel="noopener" target="_blank" title="Prague International Marathon na Instagramu"><svg class="svg-icon"><use xlink:href="#icon-social-media-instagram"></use></svg> <span class="sr-only">Prague International Marathon na Instagramu</span></a>
# </li>
# <li class="pageHeader_socialMedia_item">
# <a class="pageHeader_socialMedia_link pageHeader_socialMedia_link-youtube" href="https://www.youtube.com/runczech" rel="noopener" target="_blank" title="Prague International Marathon na YouTube"><svg class="svg-icon"><use xlink:href="#icon-social-media-youtube"></use></svg> <span class="sr-only">Prague International Marathon na YouTube</span></a>
# </li>
# <!--
# 					<li class="pageHeader_socialMedia_item">
# 						<a class="pageHeader_socialMedia_link" href="/cs/rss/aktuality.xml" title="RSS - aktuality" target="_blank"><svg class="svg-icon"><use xlink:href="#icon-rss"></use></svg> <span class="sr-only">Prague International Marathon na Facebooku</span></a>
# 					</li>
# -->
# </ul>
# </div>
# </div>
# <div class="pageHeader_container_part pageHeader_container_part-rwd">
# <form action="/srv/www/qf/en/ramjet/search" class="search js_search" method="post">
# <div class="search_wrapper">
# <label class="search_label sr-only" for="query">Find</label>
# <input class="search_input" id="query" name="query" placeholder="Search …" type="text" value=""/>
# <button class="search_button js_fulltext"><svg class="search_icon"><use xlink:href="#icon-search"></use></svg></button>
# </div>
# </form>
# <div class="languages js_languages">
# <h2 class="visuallyHidden">Language version</h2>
# <ul class="languages_list">
# <li class="languages_item languages_item-actual"><span class="languages_link"><svg class="languages_icon"><use xlink:href="#icon-flag-en"></use></svg> English <svg class="languages_select"><use xlink:href="#icon-select"></use></svg></span></li>
# <li class="languages_item"><a class="languages_link" href="/cs/"><svg class="languages_icon"><use xlink:href="#icon-flag-cs"></use></svg> Česky</a></li>
# <li class="languages_item"><a class="languages_link" href="/de/"><svg class="languages_icon"><use xlink:href="#icon-flag-de"></use></svg> Deutsch</a></li>
# <li class="languages_item"><a class="languages_link" href="/it/"><svg class="languages_icon"><use xlink:href="#icon-flag-it"></use></svg> Italiano</a></li>
# <li class="languages_item"><a class="languages_link" href="/fr/"><svg class="languages_icon"><use xlink:href="#icon-flag-fr"></use></svg> Français</a></li>
# <li class="languages_item"><a class="languages_link" href="/es/"><svg class="languages_icon"><use xlink:href="#icon-flag-es"></use></svg> Español</a></li>
# <li class="languages_item"><a class="languages_link" href="/pl/"><svg class="languages_icon"><use xlink:href="#icon-flag-pl"></use></svg> Polski</a></li>
# <li class="languages_item"><a class="languages_link" href="/zh/"><svg class="languages_icon"><use xlink:href="#icon-flag-zh"></use></svg> 中國</a></li>
# <li class="languages_item"><a class="languages_link" href="/ru/"><svg class="languages_icon"><use xlink:href="#icon-flag-ru"></use></svg> Pусский язык</a></li>
# <li class="languages_item"><a class="languages_link" href="/hu/"><svg class="languages_icon"><use xlink:href="#icon-flag-hu"></use></svg> Magyar</a></li>
# <li class="languages_item"><a class="languages_link" href="/ja/"><svg class="languages_icon"><use xlink:href="#icon-flag-ja"></use></svg> 日本語</a></li>
# <li class="languages_item languages_item-google">
# <div class="googleLanguage">
# <div class="languages_translateInfo">Please note:<br/> This is a machine translation.</div>
# <div id="google_translate_element"></div>
# <script>
# 								function googleTranslateElementInit() {
# 									new google.translate.TranslateElement({
# 										pageLanguage: 'en',
# 										autoDisplay: false,
# 										includedLanguages: 'af,sq,en,ar,be,bg,cs,zh-TW,zh-CN,da,et,tl,fi,fr,gl,ht,iw,hi,nl,hr,id,ga,is,it,ja,yi,ca,ko,lt,lv,hu,mk,ms,mt,de,no,fa,pl,pt,ro,ru,el,sk,sl,sr,sw,es,sv,th,tr,uk,eo,cy,vi',
# 										layout: google.translate.TranslateElement.InlineLayout.SIMPLE
# 									}, 'google_translate_element');
# 								}
# 							</script>
# <script src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit"></script>
# </div>
# </li>
# </ul>
# </div>
# <div class="registration js_registration">
# <a class="registration_link registration_link-runners js_registrationRunners" href="/srv/www/qf/en/ramjet/runnerProfile/loginDialog">
# <svg class="registration_icon"><use xlink:href="#icon-login"></use></svg> <span class="registration_link_text registration_link_text-longer">Runners ID: Log in</span><span class="registration_link_text registration_link_text-shorter">Runners ID</span>
# </a>
# <a class="registration_link registration_link-race js_registrationRace" href="/srv/www/qf/en/ramjet/eventList">
# <svg class="registration_icon"><use xlink:href="#icon-registration"></use></svg> <span class="registration_link_text registration_link_text-longer">Register to race</span><span class="registration_link_text registration_link_text-shorter">To the race</span>
# </a>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <div class="megaDropDownMenu js_megaDropDownMenu">
# <h2 class="visuallyHidden">Extended menu</h2>
# <div class="container">
# <div class="menu megamenu" id="events">
# <ul class="megamenu_list projects" data-actual-date="05/28/2019">
# <li class="megamenu_item" data-date="06/01/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/mattoni-ceske-budejovice-half-marathon-2019/index.shtml">Mattoni České Budějovice Half Marathon 2019</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-06-01">Jun 1, 2019</time>
# <p class="megamenu_description_hashtag">#CBhalf</p>
# <p class="buttons"><a class="button" href="/en/events/mattoni-ceske-budejovice-half-marathon-2019/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-ceske-budejovice-half-marathon-2019/races/mattoni-ceske-budejovice-half-marathon/index.shtml">Mattoni České Budějovice Half Marathon</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-ceske-budejovice-half-marathon-2019/races/mattoni-ceske-budejovice-half-marathon-relay/index.shtml">Mattoni České Budějovice Half Marathon - relay</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-ceske-budejovice-half-marathon-2019/races/2run-1011-km/index.shtml">2Run (10+11 km)</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-ceske-budejovice-half-marathon-2019/races/dm-family-run/index.shtml">dm family run</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item" data-date="06/15/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/mattoni-olomouc-half-marathon-2019/index.shtml">Mattoni Olomouc Half Marathon 2019</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-06-15">Jun 15, 2019</time>
# <p class="megamenu_description_hashtag">#OLhalf</p>
# <p class="buttons"><a class="button" href="/en/events/mattoni-olomouc-half-marathon-2019/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label="3"><a class="menu_subevent_link" href="/en/events/mattoni-olomouc-half-marathon-2019/races/mattoni-olomouc-half-marathon/index.shtml">Mattoni Olomouc Half Marathon</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-olomouc-half-marathon-2019/races/mattoni-olomouc-half-marathon-relay/index.shtml">Mattoni Olomouc Half Marathon - relay</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-olomouc-half-marathon-2019/races/2run-1011-km/index.shtml">2Run (10+11 km)</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-olomouc-half-marathon-2019/races/dm-family-run/index.shtml">dm family run</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item" data-date="06/25/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/o2-prague-relay-2019/index.shtml">O2 Prague Relay 2019</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-06-25">Jun 25 - Jun 27, 2019</time>
# <p class="megamenu_description_hashtag">#PragueRelay</p>
# <p class="buttons"><a class="button" href="/en/events/o2-prague-relay-2019/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/o2-prague-relay-2019/categories/o2-prague-relay/index.shtml">O2 Prague Relay</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/o2-prague-relay-2019/categories/bambini-run/index.shtml">Bambini Run</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/o2-prague-relay-2019/categories/diplomatic-cup/index.shtml">Diplomatic Cup</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/o2-prague-relay-2019/categories/bank-cup/index.shtml">Bank Cup</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/o2-prague-relay-2019/categories/chambers-cup/index.shtml">Chambers Cup</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/o2-prague-relay-2019/categories/medical-run/index.shtml">Medical Run</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item" data-date="09/07/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/birell-prague-grand-prix-2019/index.shtml">Birell 10 km Race Prague 2019</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-09-07">Sep 7, 2019</time>
# <p class="megamenu_description_hashtag">#PragueGrandPrix</p>
# <p class="buttons"><a class="button" href="/en/events/birell-prague-grand-prix-2019/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label="3"><a class="menu_subevent_link" href="/en/events/birell-prague-grand-prix-2019/races/birell-grand-prix-praha-2019/index.shtml">Birell 10k Race - men, women 2019</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/birell-prague-grand-prix-2019/races/birell-10k-race-teams/index.shtml">Birell 10k Race - teams</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item" data-date="09/07/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/adidas-womens-race-5km/index.shtml">adidas Women's race 5 km</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-09-07">Sep 7, 2019</time>
# <p class="megamenu_description_hashtag">#womens5k</p>
# <p class="buttons"><a class="button" href="/en/events/adidas-womens-race-5km/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/adidas-womens-race-5km/races/adidas-womens-race-5km/index.shtml">adidas Women's race 5 km</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/adidas-womens-race-5km/races/adidas-womens-race-5km-teams/index.shtml">adidas Women's race 5 km - pairs</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item" data-date="09/21/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/mattoni-usti-nad-labem-half-marathon-2018-1/index.shtml">Mattoni Ústí nad Labem Half Marathon 2019</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-09-21">Sep 21, 2019</time>
# <p class="megamenu_description_hashtag">#ULhalf</p>
# <p class="buttons"><a class="button" href="/en/events/mattoni-usti-nad-labem-half-marathon-2018-1/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label="3"><a class="menu_subevent_link" href="/en/events/mattoni-usti-nad-labem-half-marathon-2018-1/races/mattoni-usti-nad-labem-half-marathon/index.shtml">Mattoni Ústí nad Labem Half Marathon</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-usti-nad-labem-half-marathon-2018-1/races/mattoni-usti-nad-labem-half-marathon-relay/index.shtml">Mattoni Ústí nad Labem Half Marathon - relay</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-usti-nad-labem-half-marathon-2018-1/races/2run-1011-km/index.shtml">2Run (10+11 km)</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/mattoni-usti-nad-labem-half-marathon-2018-1/races/dm-family-run/index.shtml">dm family run</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item" data-date="10/05/2019">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/liberec-nature-run-2019/index.shtml">Liberec Nature Run 2019</a>
# </div><!-- wrapper -->
# <div class="megamenu_description">
# <div class="megamenu_description_container">
# <div class="megamenu_description_highlight">
# <time class="megamenu_description_time" datetime="2019-10-05">Oct 5, 2019</time>
# <p class="megamenu_description_hashtag">#LiberecNatureRun</p>
# <p class="buttons"><a class="button" href="/en/events/liberec-nature-run-2019/index.shtml">Event details</a></p>
# </div>
# <p class="menu_headline">List of races</p>
# <ul class="raceList">
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/liberec-nature-run-2019/races/liberec-nature-run-12-km/index.shtml">Liberec Nature Run - 12 km</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/liberec-nature-run-2019/races/liberec-nature-run-22-km/index.shtml">Liberec Nature Run - 22 km</a></li>
# <li data-iaaf-label=""><a class="menu_subevent_link" href="/en/events/liberec-nature-run-2019/races/dm-family-run/index.shtml">dm family run</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="megamenu_item megamenu_item-foreign">
# <div class="megamenu_menu">
# <a class="megamenu_menu_link" href="/en/events/napoli-running/index.shtml">RunCzech in the world</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="menu" id="league">
# <div class="menu_part">
# <p class="menu_headline">Running league</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/running-league/running-league/you-do-not-have-to-run-first-to-be-the-winner/index.shtml">You do not have to run first to be the winner!</a></li>
# <li><a class="menu_subevent_link" href="/srv/www/qf/en/ramjet/results/league">RunCzech Running League Ranking</a></li>
# <li><a class="menu_subevent_link" href="/en/running-league/running-league/list-of-races/index.shtml">List of races</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">Guest race</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/running-league/guest-race/istanbul-marathon/index.shtml">Istanbul marathon</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">Euroheroes</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/running-league/euroheroes/project-euroheroes/index.shtml">Project EuroHeroes</a></li>
# <li><a class="menu_subevent_link" href="/en/running-league/euroheroes/list-of-races/index.shtml">List of races</a></li>
# <li><a class="menu_subevent_link" href="/en/running-league/euroheroes/euroheroes-challenge/index.shtml">EuroHeroes Challenge</a></li>
# <li><a class="menu_subevent_link" href="/en/running-league/euroheroes/ranking-system/index.shtml">Ranking system</a></li>
# </ul>
# </div>
# </div>
# <div class="menu" id="forYou">
# <div class="menu_part">
# <p class="menu_headline">For runners</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/rules-and-general-information-1/index.shtml">Rules and general information</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/faq/index.shtml">FAQ</a></li>
# <li><a class="menu_subevent_link" href="http://www.activetimes.eu/runczechhotels/">Accommodation</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/flight-tickets/index.shtml">Flight tickets</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/travel-agencies/index.shtml">Travel Agencies</a></li>
# <li><a class="menu_subevent_link" href="http://aimsworldrunning.com/Calendar.htm">AIMS Race Calendar</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/registration-transfer-manual-and-rules/index.shtml">Registration transfer - manual and rules</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/dm-family-run/index.shtml">dm family run</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/cancellation-insurance-from-race-participation/index.shtml">Cancellation insurance from race participation</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/for-runners/authorization-to-start-number-collection/index.shtml">Authorization to start number collection</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">Communities</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/for-you/communities/pim-kings-a-pim-queens/basic-informations/index.shtml">PIM Kings and PIM Queens</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/communities/runczech-stars/index.shtml">RunCzech Stars</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/communities/first-timers/about-the-program/index.shtml">First-timers</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/communities/czech-marathon-club/basic-informations/index.shtml">Czech Marathon Club</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">Inspiration</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/for-you/inspiration/runners-stories/index.shtml">Runners' Stories</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/inspiration/aplication/index.shtml">RunCzech App</a></li>
# <li><a class="menu_subevent_link" href="http://www.runningmall.cz/en/">Running Mall</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/inspiration/runczech-story/index.shtml">RunCzech Story</a></li>
# <li><a class="menu_subevent_link" href="/en/for-you/inspiration/registration-voucher/index.shtml">Registration voucher</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">Charity</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/for-you/charity/season-2018/for-runners/run-for-a-good-cause/index.shtml">Season 2019</a></li>
# </ul>
# </div>
# </div>
# <div class="menu" id="aboutUs">
# <div class="menu_part">
# <p class="menu_headline">About us</p>
# <ul>
# <li><a class="menu_subevent_link" href="/srv/www/qf/en/ramjet/contactPage">Contact</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/about-us/history/index.shtml">History</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/about-us/iaaf-labels/index.shtml">Awards</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/about-us/our-team/index.shtml">Our team</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/about-us/our-partners/index.shtml">Our partners</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/about-us/all-runners-are-beautiful/index.shtml">All Runners Are Beautiful</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">For media</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/useful/for-the-media/press-releases/press-releases-2019/index.shtml">Press releases</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/for-the-media/for-download/magazine/2019/volkswagen-prague-marathon/index.shtml">Magazine</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/for-the-media/notes-for-editors/index.shtml">Notes for editors</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/for-the-media/news/index.shtml">News</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/for-the-media/accreditation-and-race-information/accreditation-for-mattoni-half-marathon-ceske-budejovice/index.shtml">Accreditation and race information</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">For public</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/useful/for-public/gift-the-feeling-in-the-finish-line/index.shtml">Give the feeling in the finish line</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/for-public/for-volunteers/volunteers/index.shtml">For volunteers</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/for-public/gdpr/index.shtml">GDPR</a></li>
# </ul>
# </div>
# <div class="menu_part">
# <p class="menu_headline">RunCzech Racing</p>
# <ul>
# <li><a class="menu_subevent_link" href="/en/useful/runczech-racing/about/index.shtml">About</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/runczech-racing/racing-team/index.shtml">Racing team 2018</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/runczech-racing/gallery/photo/index.shtml">Gallery</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/runczech-racing/results/2018/index.shtml">Results</a></li>
# <li><a class="menu_subevent_link" href="/en/useful/runczech-racing/news/index.shtml">News</a></li>
# <li><a class="menu_subevent_link" href="https://www.runningmall.cz/en/">Running Club</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="clearfix" id="main">
# <h1 class="sr-only">Results</h1>
# <div id="eventList">
# <ul class="indexList indexList-events blockLink"></ul>
# <div class="paginationContainer marginTop20 overflowHidden">
# <div class="total fl lightSmallText font15"></div>
# <div class="fr">
# <ul class="pagination paginationBordered noMargin vAlignMiddle">
# </ul>
# </div>
# </div>
# </div>
# <script>
# 		//<![CDATA[
# 			$(document).ajaxSend(function( event, request, settings ) {
# 				request.setRequestHeader("Accept-Language", 'en');
# 			});
#
# 			function eventList_filterResults(element) {
# 				if(element.state != "DRAFT") {
# 					return true;
# 				} else {
# 					return false;
# 				}
# 			}
#
# 		function renderResultEventList(pageNumber) {
# 			var requestParams = {};
# 			var pageSize = 15;
#
# 			pageNumber = typeof pageNumber !== 'undefined' ? pageNumber : 1;
#
# 			requestParams.page = pageNumber;
# 			requestParams.per_page = pageSize;
#
# 			actualFilterParams = requestParams;
#
# 			showLoadingOverlay();
#
# 			$.getJSON("/srv/www/api/runner-results/v1/events/?sort=-fromDate", requestParams).done(function (data) {
# 				actualResults = data;
# 				var result = data;
# 				var resultData = result.data.filter(eventList_filterResults);
# 				var $ul = $('#eventList ul');
#
# 				$ul.empty();
#
# 				if (resultData.length > 0) {
# 					for (var index in resultData) {
# 						var item = resultData[index];
# 						var eventDate = item.fromDate == item.endDate || !item.endDate ? item.fromDate : (item.fromDate + ' - ' + item.endDate);
# 						$ul.append('<li class="indexList_item"><time class="indexList_date" datetime="'+eventDate+'">'+ eventDate +'</time><h2 class="indexList_title"><a class="indexList_link name" href="/srv/www/qf/en/ramjet/resultsEventDetail?eventId='+item.id+'">'+item.title+'</a></h2></li>');
# 					}
#
# 					//pagination
# 					var pageRecordNum = ((result.pageNumber - 1) * result.pageSize);
# 					var text;
#
# 					if (result.totalNumberOfRecords > 1) {
# 						text = (pageRecordNum+1) + ' - ' + (pageRecordNum+resultData.length)+' of a total of '+result.totalNumberOfRecords+' records';
# 					} else {
# 						text = 'One record was found.';
# 					}
#
# 					$('#eventList .paginationContainer .total').text(text);
# 					$('#eventList .pagination *').remove();
#
# 					var pageNumberNavigArr = result.pageNumbersNavigation;
#
# 					for(var i in pageNumberNavigArr) {
# 						pageNumberNavigArr[i] = String(pageNumberNavigArr[i]).trim();
# 						if(pageNumberNavigArr[i] == -1) {
# 							$('#eventList .pagination').append('<li><span>…</span></li>');
# 						} else if(pageNumberNavigArr[i].indexOf("(") > -1 || pageNumberNavigArr[i] == pageNumber) {
# 							$('#eventList .pagination').append('<li><strong>'+pageNumberNavigArr[i]+'</strong></li>');
# 						} else {
# 							$('#eventList .pagination').append('<li><a href="#" data-page-number="'+pageNumberNavigArr[i]+'">'+pageNumberNavigArr[i]+'</a></li>');
# 						}
# 					}
#
# 					if(pageNumber < result.lastPageNumber) {
# 						$('#eventList .pagination').append('<li><a href="#" data-page-number="'+(+pageNumber + 1)+'" title="Next" class="next ico"></a></li>');
# 						$('#eventList .pagination').append('<li><a href="#" data-page-number="'+result.lastPageNumber+'" title="Last" class="last ico"></a></li>');
# 					} else {
# 						$('#eventList .pagination').append('<li><span title="Next" class="next ico"></span></li>');
# 						$('#eventList .pagination').append('<li><span title="Last" class="last ico"></span></li>');
# 					}
#
# 				} else {
# 					$('#eventList .paginationContainer').hide();
# 				}
#
# 				pushActualUrlState();
# 				hideLoadingOverlay();
# 			}).fail(function (jqxhr, textStatus, error) {
# 				var err = textStatus + ", " + error;
# 				console.log("Request Failed: " + err);
# 			});
# 		}
#
# 		function pushActualUrlState() {
# 			var actualUrl = window.location.pathname+'?';
#
# 			for(var paramKey in actualFilterParams) {
# 				if(paramKey == "page" || paramKey == "per_page") {
# 					actualUrl += '&' + paramKey + '=' + actualFilterParams[paramKey];
# 				} else {
# 					actualUrl += '&frm.' + paramKey + '=' + actualFilterParams[paramKey];
# 				}
# 			}
#
# 			history.pushState({}, document.title, actualUrl);
# 		}
#
# 		$(document).ready(function () {
#
# 			$('#eventList').on('click', '.pagination a', function(e) {
# 				e.preventDefault();
# 				renderResultEventList($(this).attr('data-page-number'));
# 			});
#
# 			$('#eventList').on('click', 'ul li', function(e) {
# 				e.preventDefault();
# 				window.location = $('a:first', this).attr('href');
# 			});
#
# 			renderResultEventList(1);
# 		});
#
# 		//]]>
# 	</script>
# </div>
# </div>
# <hr/>
# <div class="container">
# <div class="partners partners-main">
# <div class="partners_wrapper">
# <h2 class="partners_title"><a href="/en/useful/about-us/our-partners/index.shtml">Title partners</a></h2>
# <a href="/en/useful/about-us/our-partners/index.shtml">
# <ul class="partners_list">
# <li class="partners_item"><img alt="Volkswagen" class="partners_image" height="360" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/vw_400x360-20180417-132150.png" width="400"/></li>
# <li class="partners_item"><img alt="Mattoni" class="partners_image" height="360" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/mattoni-2.jpg" width="400"/></li>
# <li class="partners_item"><img alt="adidas" class="partners_image" height="360" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/adidas-2.jpg" width="400"/></li>
# <li class="partners_item"><img alt="Sportisimo" class="partners_image" height="360" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/sportisimo-2.jpg" width="400"/></li>
# <li class="partners_item"><img alt="Birell" class="partners_image" height="360" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/birell-2.jpg" width="400"/></li>
# <li class="partners_item"><img alt="O2" class="partners_image" height="360" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/o2-2.jpg" width="400"/></li>
# </ul>
# </a>
# </div>
# </div>
# <div class="js_partners partners_slider">
# <div class="slideContainer">
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Official partners</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="Generali" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/generali.png" width="340"/></li>
# <li class="partners_item"><img alt="dm" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-dm.png" width="340"/></li>
# <li class="partners_item"><img alt="Unicredit bank" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-unic.png" width="340"/></li>
# <li class="partners_item"><img alt="Kaufland" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/kaufland.png" width="340"/></li>
# <li class="partners_item"><img alt="Gatorade" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-gatorade.png" width="340"/></li>
# <li class="partners_item"><img alt="Hilton Hotels in Prague" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-hilton.png" width="340"/></li>
# <li class="partners_item"><img alt="České Dráhy" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/cd_narodni_dopravce_dvour_cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="Turkish Airlines" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga_turkish_airlines_400_360px.png" width="340"/></li>
# <li class="partners_item"><img alt="Czech Airlines" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_csa_2010.png" width="340"/></li>
# <li class="partners_item"><img alt="Prague Airport" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-lp.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Official media partners</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="Česká televize" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-ct.png" width="340"/></li>
# <li class="partners_item"><img alt="Seznam.cz" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-seznam.png" width="340"/></li>
# <li class="partners_item"><img alt="Radiožurnál" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/cro-radiozurnal-z-cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="Forbes" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-forbes.png" width="340"/></li>
# <li class="partners_item"><img alt="Hospodářské noviny" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-hn.png" width="340"/></li>
# <li class="partners_item"><img alt="Reportér" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_reporter.png" width="340"/></li>
# <li class="partners_item"><img alt="Deník" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-dd.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Media partners</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="Běhej srdcem" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/behej_srdcem.png" width="340"/></li>
# <li class="partners_item"><img alt="Run magazine" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-run.png" width="340"/></li>
# <li class="partners_item"><img alt="Railreklam" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/obdelnik-1.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha TV" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-prahatv.png" width="340"/></li>
# <li class="partners_item"><img alt="Český rozhlas Junior" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/-radio_junior-h-cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="Behej.com" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_behej_2016.png" width="340"/></li>
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-cvtt.png" width="340"/></li>
# <li class="partners_item"><img alt="Impact Digital Media" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-id.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Partners</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga_dodo_340_260px.png" width="340"/></li>
# <li class="partners_item"><img alt="Barilla" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/barilla.png" width="340"/></li>
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/340x260-20180814-153658.png" width="340"/></li>
# <li class="partners_item"><img alt="Hansgrohe" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-hann.png" width="340"/></li>
# <li class="partners_item"><img alt="Meggle" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/meggle-logo-4c-vektor.png" width="340"/></li>
# <li class="partners_item"><img alt="Lavazza" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/lavazza.png" width="340"/></li>
# <li class="partners_item"><img alt="Ajeto" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/lasvit_ajeto_340_260px.png" width="340"/></li>
# <li class="partners_item"><img alt="Johnny Servis" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo-johnnyservis-cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="Komwag" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-kom.png" width="340"/></li>
# <li class="partners_item"><img alt="FG Forrest" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga_fg_forrest_340_260px.png" width="340"/></li>
# <li class="partners_item"><img alt="Čechymen" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-cch.png" width="340"/></li>
# <li class="partners_item"><img alt="PRE" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-pr.png" width="340"/></li>
# <li class="partners_item"><img alt="DPP" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/dpp_partnerd_label.png" width="340"/></li>
# <li class="partners_item"><img alt="IDC-softwarehouse" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-idc.png" width="340"/></li>
# <li class="partners_item"><img alt="YVENTECH" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/yvv.png" width="340"/></li>
# <li class="partners_item"><img alt="Palestra" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-palst.png" width="340"/></li>
# <li class="partners_item"><img alt="Italsko-česká obchodní komora" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga_italsko_ceska_obchodni_komora_340_260px.png" width="340"/></li>
# <li class="partners_item"><img alt="Záchraná služba" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-za.png" width="340"/></li>
# <li class="partners_item"><img alt="Výstaviště Praha" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/rprg_vp_cz_vert_c1.png" width="340"/></li>
# <li class="partners_item"><img alt="Incheba" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-inch.png" width="340"/></li>
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/obdelnik-2.png" width="340"/></li>
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/fithero.png" width="340"/></li>
# <li class="partners_item"><img alt="Národní muzeum" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logonm_cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="Spolchemie" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-spol.png" width="340"/></li>
# <li class="partners_item"><img alt="Active Times" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/active-times-final-vertical.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Regional partners</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/charita/trend_stredni.jpg" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Patrons</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="European Athl" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/european_athletics_340_260px.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_praha.png" width="340"/></li>
# <li class="partners_item"><img alt="CzechTourism" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-ctou.png" width="340"/></li>
# <li class="partners_item"><img alt="MSMT" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/v_logotype_cz_cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="ČAS" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/cas_barva_final.png" width="340"/></li>
# <li class="partners_item"><img alt="" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-cov.png" width="340"/></li>
# <li class="partners_item"><img alt="Evropská komise" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-k.png" width="340"/></li>
# <li class="partners_item"><img alt="AIMS" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-aims.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Institutions</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="Praha 1" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/praha1_kompaktni-logo_color.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha 2" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_praha_2.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha 4" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_praha4_ok.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha 5" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_p5mc_b_neg.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha 7" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_praha7_1_c.png" width="340"/></li>
# <li class="partners_item"><img alt="Praha 8" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo_praha8.png" width="340"/></li>
# <li class="partners_item"><img alt="Pražské Jaro" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/loga-pj_vyska_bez_rocnik_cz.png" width="340"/></li>
# <li class="partners_item"><img alt="Prague City Tourism" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/prague-city-tourism_logo_s_claimem_cmyk_pozitiv-20180115-142857.png" width="340"/></li>
# <li class="partners_item"><img alt="Karlova Univerzita" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/uzitna_iv_cz_krivky_cmyk.png" width="340"/></li>
# <li class="partners_item"><img alt="FTVS" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/ukftvs_logo_cmyk.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Regionální partneři - Olomouc</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="dpmo" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/dpmo.png" width="340"/></li>
# <li class="partners_item"><img alt="pevnost poznání" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/pevnostpoznani.png" width="340"/></li>
# <li class="partners_item"><img alt="šantovka" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo2.png" width="340"/></li>
# <li class="partners_item"><img alt="AGEL" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/agel.png" width="340"/></li>
# <li class="partners_item"><img alt="autocentrum OL" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/aco.png" width="340"/></li>
# <li class="partners_item"><img alt="drapal" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logoweb.png" width="340"/></li>
# <li class="partners_item"><img alt="vystaviste OL" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/vfo_nove_logo.png" width="340"/></li>
# <li class="partners_item"><img alt="Omega" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/omega.png" width="340"/></li>
# <li class="partners_item"><img alt="drbna OL" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/logo-header.png" width="340"/></li>
# <li class="partners_item"><img alt="radio hana" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/hana.png" width="340"/></li>
# <li class="partners_item"><img alt="radio cas" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/cas.png" width="340"/></li>
# <li class="partners_item"><img alt="OL4you" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/ol4y.png" width="340"/></li>
# <li class="partners_item"><img alt="NH olomouc" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/c_marca_hotel_v.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="categoryWrapper">
# <div class="partners">
# <div class="partners_wrapper">
# <h2 class="partners_title">Regional partners - Liberec</h2>
# <ul class="partners_list">
# <li class="partners_item"><img alt="Liberec město" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/liberec_city.png" width="340"/></li>
# <li class="partners_item"><img alt="Liberec kraj" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/liberecky_kraj.png" width="340"/></li>
# <li class="partners_item"><img alt="AutoTrend" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/autotrend.png" width="340"/></li>
# <li class="partners_item"><img alt="Nemocnice Liberec" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/krajska_nemocnice_liberec.png" width="340"/></li>
# <li class="partners_item"><img alt="Tulipán" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/sdruzeni_tulipan.png" width="340"/></li>
# <li class="partners_item"><img alt="Český rozhlas Liberec" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/cro_liberec.png" width="340"/></li>
# <li class="partners_item"><img alt="Sport park Medical" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/sport_park_medical.png" width="340"/></li>
# <li class="partners_item"><img alt="Sport Park Liberec" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/sport_park_liberec.png" width="340"/></li>
# <li class="partners_item"><img alt="nyc sport" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/nyc_sport.png" width="340"/></li>
# <li class="partners_item"><img alt="ASP Group Liberec" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/aspgroup.png" width="340"/></li>
# <li class="partners_item"><img alt="Technická univerzita v Liberci" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/technicka_univerzita_liberec.png" width="340"/></li>
# <li class="partners_item"><img alt="Technické muzeum Liberec" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/technicke_muzeum_liberec.png" width="340"/></li>
# <li class="partners_item"><img alt="Forum Liberec" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/forum_liberec.png" width="340"/></li>
# <li class="partners_item"><img alt="Grand hotel Imperiál" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/grand_hote_imperiall_pytloun.png" width="340"/></li>
# <li class="partners_item"><img alt="Ligranit" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/ligranit.png" width="340"/></li>
# <li class="partners_item"><img alt="Liberecká drbna" class="partners_image" height="260" src="https://cdn-vsh.runczech.com/file/edee/universal/partners/liberecka_drbna.png" width="340"/></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr/>
# <footer class="pageFooter">
# <div class="container">
# <!--FG(part.default)-->
# <div class="pageFooter_socialMedia">
# <ul class="pageFooter_socialMedia_list">
# <li class="pageFooter_socialMedia_item">
# <a class="pageFooter_socialMedia_link pageFooter_socialMedia_link-facebook" href="https://www.facebook.com/runczech" rel="noopener" target="_blank" title="Prague International Marathon on Facebook"><svg class="svg-icon"><use xlink:href="#icon-social-media-facebook"></use></svg> <span class="sr-only">Prague International Marathon on Facebook</span></a>
# </li>
# <li class="pageFooter_socialMedia_item">
# <a class="pageFooter_socialMedia_link pageFooter_socialMedia_link-twitter" href="https://twitter.com/RunCzech" rel="noopener" target="_blank" title="Prague International Marathon on Twitter"><svg class="svg-icon"><use xlink:href="#icon-social-media-twitter"></use></svg> <span class="sr-only">Prague International Marathon on Twitter</span></a>
# </li>
# <li class="pageFooter_socialMedia_item">
# <a class="pageFooter_socialMedia_link pageFooter_socialMedia_link-flickr" href="https://www.flickr.com/photos/runczech/" rel="noopener" target="_blank" title="Prague International Marathon on Flickr"><svg class="svg-icon"><use xlink:href="#icon-social-media-flickr"></use></svg> <span class="sr-only">Prague International Marathon on Flickr</span></a>
# </li>
# <li class="pageFooter_socialMedia_item">
# <a class="pageFooter_socialMedia_link pageFooter_socialMedia_link-instagram" href="https://www.instagram.com/runczech/?hl=en" rel="noopener" target="_blank" title="Prague International Marathon on Instagram"><svg class="svg-icon"><use xlink:href="#icon-social-media-instagram"></use></svg> <span class="sr-only">Prague International Marathon on Instagram</span></a>
# </li>
# <li class="pageFooter_socialMedia_item">
# <a class="pageFooter_socialMedia_link pageFooter_socialMedia_link-youtube" href="https://www.youtube.com/runczech" rel="noopener" target="_blank" title="Prague International Marathon on YouTube"><svg class="svg-icon"><use xlink:href="#icon-social-media-youtube"></use></svg> <span class="sr-only">Prague International Marathon on YouTube</span></a>
# </li>
# <!--
# 				<li class="pageFooter_socialMedia_item">
# 					<a class="pageFooter_socialMedia_link" href="&lt;!&ndash;FG(page['p.rss.news'].url)&ndash;&gt;" title="&lt;!&ndash;FG(page['p.rss.news'].name)&ndash;&gt;" target="_blank"><svg class="svg-icon"><use xlink:href="#icon-rss"></use></svg> <span class="sr-only">&lt;!&ndash;FG(snippet['pimOnFacebook'])&ndash;&gt;</span></a>
# 				</li>
# -->
# </ul>
# </div>
# <div class="pageFooter_bar">
# <div class="pageFooter_copyright">
# <p>© 2019 Prague International Marathon - Maraton Praha</p>
# <p class="pageFooter_anchors">
# <a class="pageFooter_anchors_link" href="/en/web-information/index.shtml">Web information</a><span class="pageFooter_divider">|</span>
# <a class="pageFooter_anchors_link" href="/en/sitemap/index.shtml">Site map</a><span class="pageFooter_divider">|</span>
# <a class="pageFooter_anchors_link" href="/srv/www/personal-data-en">GDPR</a>
# </p>
# </div>
# <ul class="pageFooter_marks">
# <li class="pageFooter_marks_item">
# <span class="pageFooter_marks_label">Made by:</span>
# <a class="pageFooter_marks_link pageFooter_marks_link-fg" href="https://www.fg.cz" title="Produced and administrated by FG Forrest, a.s."><svg class="svg-icon"><use xlink:href="#icon-fg"></use></svg> <span class="sr-only">FG Forrest</span></a>
# <a class="pageFooter_marks_link pageFooter_marks_link-edee" href="http://www.edee.one" title="Edee.one – CMS &amp; E-commerce platform"><svg class="svg-icon"><use xlink:href="#icon-edee"></use></svg> <span class="sr-only">Edee CMS</span></a>
# </li>
# <li class="pageFooter_marks_item">
# <span class="pageFooter_marks_label">Powered by:</span>
# <a class="pageFooter_marks_link pageFooter_marks_link-idc" href="http://www.idc.cz/" title="Powered by IDC"><svg class="svg-icon"><use xlink:href="#icon-idc"></use></svg> <span class="sr-only">IDC</span></a>
# </li>
# </ul>
# </div>
# </div>
# <!--	<div class="newsletterSubscription">
# 		<form class="newsletterSubscription_form" id="newsletterSubscribeForm" action="&lt;!&ndash;FG(page['p.newsletter'].url)&ndash;&gt;/newsletterSubscribeForm" method="get">
# 			<input type="hidden" name="eventName.send" value="">
# 			<label class="newsletterSubscription_label" for="emailInput">&lt;!&ndash;FG(snippet['nl-subscribe-email-label'])&ndash;&gt;</label>
# 			<div class="newsletterSubscription_inputs">
# 				<input class="newsletterSubscription_inputs_text" type="email" name="frm.email" placeholder="&lt;!&ndash;FG(snippet['nl-subscribe-email-placeholder'])&ndash;&gt;" value="" id="emailInput" />
# 				<input id="newsletterSubscribe" type="submit" name="newsletterSubscribe" value="&lt;!&ndash;FG(snippet['nl-subscribe-submit-title'])&ndash;&gt;" class="button newsletterSubscription_inputs_button" />
# 			</div>
# 			<span class="newsletterSubscription_message">&lt;!&ndash;FG(snippet['nl-subscribe-message'])&ndash;&gt;</span>
# 		</form>
# 	</div>-->
# </footer>
# </body></html>

# %% [markdown]
# No middlepage table can be found in output as it's loaded via javascript. The eventID is pulled from somewhere (their servers, JSON) only upon loading the page using their script.
#
# This is inside of the script that has the crucial eventId='+item.id+' that is not statically in the HTML:
#
# ```<a class="indexList_link name" href="/srv/www/qf/en/ramjet/resultsEventDetail?eventId='+item.id+'">```
#
# Once the webpage is loaded in the browser, this is how the link we seek looks like, already the eventID is rendered to the code:
#
# ```<a class="indexList_link name" href="/srv/www/qf/en/ramjet/resultsEventDetail?eventId=22175">Mattoni Karlovy Vary Half Marathon - 21.0975 km 2019</a>```
#
# See how the browser renders the eventID into the HTML using the script (links_tag_js_issue.png):

# %% [markdown]
# <img src="v0-links_tag_js_issue.png">

# %% [markdown]
# ### Find all marathon links

# %% [markdown]
# Proceed to check programmatically that we cannot pull any links from the middlepage table as it's not in the scraped static HTML code. It gets loaded in the browser only after we load the page, via javascript. Nonetheless, this is how we'd scrape the "a href" tag of class "indexList_link" if we had a static webpage with links:

# %%
def getAllLinks(link):
    soup = getSoup(link)

    a_elements = soup.findAll('a',{'class':'indexList_link'}) # class "indexList_link" contains the href link we desire
                
    return ['https://www.runczech.com/' + a.find('a')['href'] for a in a_elements] # list comprehension/function for links
    
marathons_links = getAllLinks('https://www.runczech.com/srv/www/qf/en/ramjet/results/list?&page=1&per_page=15')

# %%
marathons_links
# Out:
# []

# %% [markdown]
# No such links can be found in output as it's loaded via javascript dynamically and we're scraping statically.

# %% [markdown]
# ### Scrape a single table
#
# Just an outline of how it could be coded in a static html page follows:

# %%
def getNames(link):
    soup = getSoup(link)

    trs = soup.findAll('tr') # "tr" table-row element tag
    
    el = ['https://www.runczech.com/' + tr.find('td',{'class':'hidden980'}) for tr in trs] # hidden980 is class of first column
    sibling = el.next_sibling
    
#     return sibling.next_sibling # names are next to sibling of hidden980 class element/column
    return soup
    
names = getNames('https://www.runczech.com/srv/www/qf/en/ramjet/resultsEventDetail?eventId=21429&frm.subeventId=21430&page=1&per_page=15&sort=finishTime')

# %%
names

# %%
def getTimes(link):
    soup = getSoup(link)

    trs = soup.findAll('tr') # "tr" table-row element tag
    
    el = ['https://www.runczech.com/' + tr.find('td',{'class':'hidden767'}) for tr in trs] # hidden767 is class of "Chip time" column
    
#     return el
    return soup
    
times = getTimes('https://www.runczech.com/srv/www/qf/en/ramjet/resultsEventDetail?eventId=21429&frm.subeventId=21430&page=1&per_page=15&sort=finishTime')

# %%
times

# %% [markdown]
# ### HELP - scraping javascript dynamic website
#  - https://www.google.com/search?q=python+scrape+website+that+has+script+inside+html&oq=python+scrape+website+that+has+script+inside+html&aqs=chrome..69i57.14882j0j7&sourceid=chrome&ie=UTF-8
#      - https://stackoverflow.com/questions/26680590/how-to-scrape-imbeded-script-on-webpage-in-python
#      - https://stanford.edu/~mgorkove/cgi-bin/rpython_tutorials/Scraping_a_Webpage_Rendered_by_Javascript_Using_Python.php
#      - https://www.youtube.com/watch?v=FSH77vnOGqU
#      - https://www.youtube.com/watch?v=vsmxMLmroyQ

# %% [markdown]
# ### Reworking the above static scraping into JS scraping:

# %%
#Verze 1 :

from selenium import webdriver

# %%
#Working with chrome, first opens window, then browser gets all source code

browser = webdriver.Chrome()    
url = "https://www.runczech.com/srv/www/qf/cs/ramjet/results/list?&page=1&per_page=15"
#url = "https://www.runczech.com/srv/www/qf/cs/ramjet/resultsEventDetail?eventId=22175&frm.subeventId=22176&page=1&per_page=15&sort=finishTime"
browser.get(url) #navigate to the page

# %%
# Takes all the inner code

innerHTML = browser.execute_script("return document.body.innerHTML") #returns the inner HTML as a string
str(innerHTML)
# Out:
# '<div class="hide"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><clipPath id="a"><path fill-opacity=".67" d="M-74 0h682.67v512H-74z"></path></clipPath><clipPath id="a"><path fill-opacity=".67" d="M-85.333 0h682.67v512h-682.67z"></path></clipPath><clipPath id="a"><path fill-opacity=".67" d="M-88.001 32h640v480h-640z"></path></clipPath></defs><symbol id="icon-edee" viewBox="0 0 59.1 19"><path class="st0" d="M6.6 13.534c-.8.4-1.6.6-2.5.6-.7.1-1.4-.3-1.9-.9-.2-.4-.3-.8-.3-1.2 3.5.1 5.9-.6 5.9-2.7 0-1.5-1.2-2.4-2.9-2.4-2.8.1-5 2.4-4.9 5.2-.2 1.8 1.2 3.4 3 3.6h.7c1.1 0 2.2-.2 3.2-.7l-.3-1.5zm-.7-4.2c0 1-1.4 1.2-3.7 1.2.3-1.2 1.3-2 2.5-2.1.7.1 1.2.4 1.2.9zM15.4 3.234l-.7 4c-.5-.2-.9-.2-1.4-.2-3 0-5.5 2.4-5.5 5.4v.1c0 2 1.2 3.3 2.8 3.3 1.3 0 2.4-.7 3.1-1.8l-.2 1.6h1.9c.1-1 .2-2 .4-3l1.7-9.3-2.1-.1zm-1.5 7.9c-.3 1.9-1.6 3-2.6 3s-1.5-.9-1.5-1.9c-.1-1.8 1.3-3.4 3.1-3.6h.1c.5 0 .9.1 1.3.3l-.4 2.2zM23.2 13.534c-.8.4-1.6.6-2.5.6-.7.1-1.4-.3-1.9-.9-.2-.4-.3-.8-.3-1.2 3.5.1 5.9-.6 5.9-2.7 0-1.5-1.2-2.4-2.9-2.4-2.8.1-5 2.4-4.9 5.2-.2 1.8 1.2 3.4 3 3.6h.7c1.1 0 2.2-.2 3.2-.7l-.3-1.5zm-.7-4.2c0 1-1.4 1.2-3.7 1.2.3-1.2 1.3-2 2.5-2.1.7.1 1.2.4 1.2.9z"></path><path class="st0" d="M30.9 13.534c-.8.4-1.6.6-2.5.6-.7.1-1.4-.3-1.9-.9-.2-.4-.3-.8-.3-1.2 3.5.1 5.9-.6 5.9-2.7 0-1.5-1.2-2.4-2.9-2.4-2.8.1-5 2.4-4.9 5.2-.2 1.8 1.2 3.4 3 3.6h.7c1.1 0 2.2-.2 3.2-.7l-.3-1.5zm-.7-4.2c0 1-1.4 1.2-3.7 1.2.3-1.2 1.3-2 2.5-2.1.7.1 1.2.4 1.2.9zM32.9 15.734c.6 0 1.1-.5 1.1-1.1v-.1c0-.5-.4-1-.9-1.1H33c-.6 0-1.1.5-1.1 1.1v.1c0 .6.4 1.1 1 1.1zM38.2 15.734c2.7 0 4.9-2.2 4.9-4.9v-.1c.1-1.9-1.3-3.6-3.3-3.7h-.4c-2.7 0-4.9 2.2-4.9 4.9v.2c-.1 1.9 1.4 3.5 3.3 3.6h.4zm.1-1.1c-1.3 0-2.3-1-2.3-2.3v-.2c0-2 1.3-3.9 3.2-3.9 1.3 0 2.3 1.1 2.3 2.4v.1c0 2.1-1.4 3.9-3.2 3.9zM44.5 15.534l.7-3.8c.4-2.2 2-3.5 3.1-3.5s1.5.7 1.5 1.6c0 .4 0 .7-.1 1l-.9 4.6h1.5l.9-4.7c.1-.4.1-.9.2-1.3.2-1.2-.7-2.3-1.9-2.5h-.4c-1.4 0-2.6.8-3.3 1.9l.2-1.7h-1.3c-.1.7-.2 1.4-.4 2.3l-1.1 6h1.3zM57.9 13.934c-.8.4-1.6.6-2.5.6-.8.1-1.6-.4-2-1.1-.2-.5-.3-1-.2-1.5 3.3.1 5.9-.4 5.9-2.6 0-1.3-1-2.2-2.6-2.2-2.7 0-4.8 2.7-4.8 5.3-.2 1.7 1.1 3.3 2.9 3.5h.5c1 0 2-.2 3-.7l-.2-1.3zm-.2-4.7c0 1.3-1.8 1.5-4.4 1.5.3-1.4 1.5-2.4 2.9-2.6.9 0 1.5.4 1.5 1.1z"></path></symbol><symbol id="icon-fg" viewBox="0 0 19 19"><path class="st0" d="M19 17.5v-16c0-.8-.7-1.5-1.5-1.5h-16C.7 0 0 .7 0 1.5v15.9c0 .9.7 1.6 1.5 1.6h15.9c.9 0 1.6-.7 1.6-1.5zm-11.6-9c0 .3-.1.6-.1 1V9.8c0 .3 0 .5.1.8H5.5V14H3V4.8h5.6v.7c-.3.4-.5.8-.7 1.3H5.5v1.7h1.9zm9 5.1c-1 .3-2.1.5-3.2.5-1.3.1-2.5-.3-3.4-1.3-.9-.8-1.4-2-1.4-3.3 0-3.2 1.9-4.9 4.9-4.9.9 0 1.8.1 2.7.5l-.5 2c-.7-.3-1.5-.4-2.2-.4-1.4 0-2.4 1.2-2.4 2.5v.1c0 1.7 1 2.7 2.2 2.7.3 0 .5 0 .8-.1v-1.6h-1.2V8.5h3.6l.1 5.1z"></path></symbol><symbol id="icon-flag-cs" viewBox="0 0 640 480"><g fill-rule="evenodd" clip-path="url(#a)" transform="translate(69.38) scale(.94)" stroke-width="1pt"><path fill="#e80000" d="M-74 0h768v512H-74z"></path><path fill="#fff" d="M-74 0h768v256H-74z"></path><path d="M-74 0l382.73 255.67L-74 511.01V0z" fill="#00006f"></path></g></symbol><symbol id="icon-flag-de" viewBox="0 0 640 480"><path fill="#ffce00" d="M0 320h640v160.002H0z"></path><path d="M0 0h640v160H0z"></path><path fill="#d00" d="M0 160h640v160H0z"></path></symbol><symbol id="icon-flag-en" viewBox="0 0 640 480"><g clip-path="url(#a)" transform="translate(80) scale(.94)"><g stroke-width="1pt"><path fill="#006" d="M-256 0H768.02v512.01H-256z"></path><path d="M-256 0v57.244l909.535 454.768H768.02V454.77L-141.515 0H-256zM768.02 0v57.243L-141.515 512.01H-256v-57.243L653.535 0H768.02z" fill="#fff"></path><path d="M170.675 0v512.01h170.67V0h-170.67zM-256 170.67v170.67H768.02V170.67H-256z" fill="#fff"></path><path d="M-256 204.804v102.402H768.02V204.804H-256zM204.81 0v512.01h102.4V0h-102.4zM-256 512.01L85.34 341.34h76.324l-341.34 170.67H-256zM-256 0L85.34 170.67H9.016L-256 38.164V0zm606.356 170.67L691.696 0h76.324L426.68 170.67h-76.324zM768.02 512.01L426.68 341.34h76.324L768.02 473.848v38.162z" fil ...

# %%
from lxml import html

# %%
# Continues with the innerHTML retrieved from previous step

htmlElem = html.document_fromstring(innerHTML) #make HTML element object

# %%
htmlElem
# Out:
# <Element html at 0x7f2d047a94f8>

# %%
# ????

tdElem1 = htmlElem.cssselect("[valign=top]")[0] #first td elem 
text = elem.text_content()
splitText = text.split("\n") #returns list of text in between "\n" chars
print(splitText)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/envs/snowflake/lib/python3.7/site-packages/lxml/cssselect.py in <module>
#      12 try:
# ---> 13     import cssselect as external_cssselect
#      14 except ImportError:
#
# ModuleNotFoundError: No module named 'cssselect'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-67ae6ced23a0> in <module>
#       2 # ????
#       3
# ----> 4 tdElem1 = htmlElem.cssselect("[valign=top]")[0] #first td elem
#       5 text = elem.text_content()
#       6 splitText = text.split("\n") #returns list of text in between "\n" chars
#
# ~/anaconda3/envs/snowflake/lib/python3.7/site-packages/lxml/html/__init__.py in cssselect(self, expr, translator)
#     429         """
#     430         # Do the import here to make the dependency optional.
# --> 431         from lxml.cssselect import CSSSelector
#     432         return CSSSelector(expr, translator=translator)(self)
#     433
#
# ~/anaconda3/envs/snowflake/lib/python3.7/site-packages/lxml/cssselect.py in <module>
#      14 except ImportError:
#      15     raise ImportError(
# ---> 16         'cssselect does not seem to be installed. '
#      17         'See http://packages.python.org/cssselect/')
#      18
#
# ImportError: cssselect does not seem to be installed. See http://packages.python.org/cssselect/

# %%
#Verze 2, podle YT:

https://www.youtube.com/watch?v=FSH77vnOGqU

# %%
#Zvláštní import...

import urllib.request

# %%
# Funguje !!! Output je ten text pod obeázkem jednorožce

source = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/')
soup = BeautifulSoup(source, 'lxml')
jstest = soup.find( class_ = 'introduction')

# %%
print(jstest.text)
# Out:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.

# %%
source2 = urllib.request.urlopen('https://www.runczech.com/srv/www/qf/cs/ramjet/resultsEventDetail?eventId=22175&frm.subeventId=22176&page=1&per_page=15&sort=finishTime')
soup2 = BeautifulSoup(source2, 'lxml')

#jstest2 = soup2.find( class_ ='pageHeadline_content')      # Tenhle odkaz třeba funguje !!

# jstest2 = soup.find_all('tr')                           # Taky nějak funguje


jstest2 = soup2.find( 'div', class_ = 'resultTable')['data-runner-id']     # tenhle zatím nefunguje... !!!!!



# soup.find('tr', {'data-runner-id'})['data-runner-id']
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-151-442e6f7fdd3c> in <module>()
#       2
#       3
# ----> 4 source2 = urllib.request.urlopen('https://www.runczech.com/srv/www/qf/cs/ramjet/resultsEventDetail?eventId=22175&frm.subeventId=22176&page=1&per_page=15&sort=finishTime')
#       5 soup2 = BeautifulSoup(source2, 'lxml')
#       6
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
print(jstest2)
# Out:
# [<tr>
# <th>Program Name</th>
# <th>Internet Points</th>
# <th>Kittens?</th>
# </tr>, <tr>
# <td>Python</td>
# <td>932914021</td>
# <td>Definitely</td>
# </tr>, <tr>
# <td>Pascal</td>
# <td>532</td>
# <td>Unlikely</td>
# </tr>, <tr>
# <td>Lisp</td>
# <td>1522</td>
# <td>Uncertain</td>
# </tr>, <tr>
# <td>D#</td>
# <td>12</td>
# <td>Possibly</td>
# </tr>, <tr>
# <td>Cobol</td>
# <td>3</td>
# <td>No.</td>
# </tr>, <tr>
# <td>Fortran</td>
# <td>52124</td>
# <td>Yes.</td>
# </tr>, <tr>
# <td>Haskell</td>
# <td>24</td>
# <td>lol.</td>
# </tr>]

# %%
# https://srome.github.io/Parsing-HTML-Tables-in-Python-with-BeautifulSoup-and-pandas/

# Taky zatím enfunguje.....



source2 = urllib.request.urlopen('https://www.runczech.com/srv/www/qf/cs/ramjet/resultsEventDetail?eventId=22175&frm.subeventId=22176&page=1&per_page=15&sort=finishTime')

page = requests.get(source2)

doc = lh.fromstring(page.content)

tr_elements = doc.xpath('//td')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-133-542740505c63> in <module>()
#       1 source2 = urllib.request.urlopen('https://www.runczech.com/srv/www/qf/cs/ramjet/resultsEventDetail?eventId=22175&frm.subeventId=22176&page=1&per_page=15&sort=finishTime')
#       2
# ----> 3 page = requests.get(source2)
#       4
#       5 doc = lh.fromstring(page.content)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     492             hooks=hooks,
#     493         )
# --> 494         prep = self.prepare_request(req)
#     495
#     496         proxies = proxies or {}
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     435             auth=merge_setting(auth, self.auth),
#     436             cookies=merged_cookies,
# --> 437             hooks=merge_hooks(request.hooks, self.hooks),
#     438         )
#     439         return p
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     303
#     304         self.prepare_method(method)
# --> 305         self.prepare_url(url, params)
#     306         self.prepare_headers(headers)
#     307         self.prepare_cookies(cookies)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     377             error = error.format(to_native_string(url, 'utf8'))
#     378
# --> 379             raise MissingSchema(error)
#     380
#     381         if not host:
#
# MissingSchema: Invalid URL '<http.client.HTTPResponse object at 0x00000174E921E748>': No schema supplied. Perhaps you meant http://<http.client.HTTPResponse object at 0x00000174E921E748>?
